# %%
from prep_prs import summary_stats_prep
from prs_graph import prs_graph

# %% [markdown]
# # Distribution Plot for PRS

# %% [markdown]
# ## Data Prep

# %% [markdown]
# The data is from Gwas Catalog, here we are using 'prepare_summary_stats_for_prs' which we implemented in prep_prs.py to help us convert the data into the format we want.

# %%
summary_stats_prep("data/hight_data.gwas.txt", ['SNP', 'ALLELE', 'BETA'], "data/prs/hight_data.txt", " ")

# %%
summary_stats_prep("data/ankylosing_spon.tsv", ['rsid', 'effect_allele', 'beta'], "data/prs/ankylosing.txt", "\t")
# Out:
# /var/folders/rn/8krws_b93vv3ckfsgwjhq5z80000gn/T/ipykernel_9920/3483488525.py:1: DtypeWarning: Columns (0) have mixed types.Specify dtype option on import or set low_memory=False.
#   prepare_summary_stats_for_prs("data/ankylosing_spon.tsv", ['rsid', 'effect_allele', 'beta'], "data/prs/ankylosing.txt", "\t")

# %%
summary_stats_prep("data/asthma.gz", ['SNP', 'ALLELE0', 'BETA'], "data/prs/asthma.txt", " ")

# %% [markdown]
# ## Run PRS

# %%
! ./plink --bfile data/final_combined --score data/prs/hight_data.txt 1 2 3 --out data/profile/prs_for_hight --allow-extra-chr
# Out:
# PLINK v1.9.0-b.7.6 64-bit (13 Oct 2024)            cog-genomics.org/plink/1.9/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to data/profile/prs_for_hight.log.
# Options in effect:
#   --allow-extra-chr
#   --bfile data/final_combined
#   --out data/profile/prs_for_hight
#   --score data/prs/hight_data.txt 1 2 3
#
# 32768 MB RAM detected; reserving 16384 MB for main workspace.
# 1515340 variants loaded from .bim file.
# 490 people (0 males, 1 female, 489 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to data/profile/prs_for_hight.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 490 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.747417.
# ...

# %%
! ./plink --bfile data/final_combined --score data/prs/ankylosing.txt 1 2 3 --out data/profile/prs_for_ankylosing --allow-extra-chr
# Out:
# PLINK v1.9.0-b.7.6 64-bit (13 Oct 2024)            cog-genomics.org/plink/1.9/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to data/profile/prs_for_ankylosing.log.
# Options in effect:
#   --allow-extra-chr
#   --bfile data/final_combined
#   --out data/profile/prs_for_ankylosing
#   --score data/prs/ankylosing.txt 1 2 3
#
# 32768 MB RAM detected; reserving 16384 MB for main workspace.
# 1515340 variants loaded from .bim file.
# 490 people (0 males, 1 female, 489 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to data/profile/prs_for_ankylosing.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 490 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# ...

# %%
! ./plink --bfile data/final_combined --score data/prs/asthma.txt 1 2 3 --out data/profile/prs_for_asthma --allow-extra-chr
# Out:
# PLINK v1.9.0-b.7.6 64-bit (13 Oct 2024)            cog-genomics.org/plink/1.9/
# (C) 2005-2024 Shaun Purcell, Christopher Chang   GNU General Public License v3
# Logging to data/profile/prs_for_asthma.log.
# Options in effect:
#   --allow-extra-chr
#   --bfile data/final_combined
#   --out data/profile/prs_for_asthma
#   --score data/prs/asthma.txt 1 2 3
#
# 32768 MB RAM detected; reserving 16384 MB for main workspace.
# 1515340 variants loaded from .bim file.
# 490 people (0 males, 1 female, 489 ambiguous) loaded from .fam.
# Ambiguous sex IDs written to data/profile/prs_for_asthma.nosex .
# Using 1 thread (no multithreaded calculations invoked).
# Before main variant filters, 490 founders and 0 nonfounders present.
# Calculating allele frequencies... 10111213141516171819202122232425262728293031323334353637383940414243444546474849505152535455565758596061626364656667686970717273747576777879808182838485868788899091929394959697989 done.
# Total genotyping rate is 0.747417.
# ...

# %% [markdown]
# ## Make the Graph
#
# Here, we impelement the helper method plot_prs_dist in prs_graph.py to help us make the distribution graph

# %%
prs_graph('data/profile/prs_for_hight.profile',"Hight", "Tiffany")

# %%
prs_graph('data/profile/prs_for_ankylosing.profile',"Ankylosing", "Tiffany")

# %%
prs_graph('data/profile/prs_for_asthma.profile',"Asthma", "Tiffany")
